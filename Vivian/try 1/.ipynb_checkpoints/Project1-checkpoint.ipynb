# %% [markdown]
# ## The project aims at helping the lending club decide wether a person is qualified for sanctioning a loan or not in the future

# %% [markdown]
# # 1.  Dataset processing

# %%
#import libraries I need, and I will add more with the project going........

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
'''Define a variable that points to the folder where data is stored'''
#my_path = '/Users/maqiang/Desktop/studymaterial/DataScience/DataScienceProject/lending-club-loan-data'
# Out:
# 'Define a variable that points to the folder where data is stored'

# %%
# reading the dataset
#df_loan = pd.read_csv(f'{my_path}/loan.csv',low_memory = False)
df_loan = pd.read_csv("/Users/maqiang/Desktop/studymaterial/DataScience/DataScienceProject/lend/loan.csv", low_memory=False)
#print(df_loan.shape)
df_loan.head(13)
#df_loan.describe()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN       2500         2500           2500.0   36 months
# 1  NaN        NaN      30000        30000          30000.0   60 months
# 2  NaN        NaN       5000         5000           5000.0   36 months
# 3  NaN        NaN       4000         4000           4000.0   36 months
# 4  NaN        NaN      30000        30000          30000.0   60 months
# 5  NaN        NaN       5550         5550           5550.0   36 months
# 6  NaN        NaN       2000         2000           2000.0   36 months
# 7  NaN        NaN       6000         6000           6000.0   36 months
# 8  NaN        NaN       5000         5000           5000.0   36 months
# 9  NaN        NaN       6000         6000           6000.0   36 months
# 10 NaN        NaN       5500         5500           5500.0   36 months
# 11 NaN        NaN      28000        28000          28000.0   60 months
# ...

# %%
#delete the colums that all are the NULLS
df_loan.dropna(axis=1,how='all')
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0             2500         2500           2500.0   36 months     13.56
# 1            30000        30000          30000.0   60 months     18.94
# 2             5000         5000           5000.0   36 months     17.97
# 3             4000         4000           4000.0   36 months     18.94
# 4            30000        30000          30000.0   60 months     16.14
# 5             5550         5550           5550.0   36 months     15.02
# 6             2000         2000           2000.0   36 months     17.97
# 7             6000         6000           6000.0   36 months     13.56
# 8             5000         5000           5000.0   36 months     17.97
# 9             6000         6000           6000.0   36 months     14.47
# 10            5500         5500           5500.0   36 months     22.35
# 11           28000        28000          28000.0   60 months     11.31
# ...

# %%
#Finding the the count and percentage of values that are missing in the dataframe.
df_null = pd.DataFrame({'Count': df_loan.isnull().sum(), 'Percent': 100*df_loan.isnull().sum()/len(df_loan)})

#printing columns with null count more than 0
df_null[df_null['Count'] > 0] 

# the size of our datasets is large， it is not good by using graph 
#null_vals = df_loan.isnull().sum()/len(df_loan)*100
#null_vals = pd.DataFrame(null_vals)
#null_vals.reset_index(inplace = True)
#null_vals.columns = ["Feature","Percent missing"]
#plt.figure(figsize = (20,10))
#plt.xticks(rotation=45)
#sns.barplot(x = "Feature",y ="Percent missing",data = null_vals)*/
# Out:
#                                               Count     Percent
# id                                          2260668  100.000000
# member_id                                   2260668  100.000000
# emp_title                                    166969    7.385826
# emp_length                                   146907    6.498389
# annual_inc                                        4    0.000177
# url                                         2260668  100.000000
# desc                                        2134601   94.423462
# title                                         23325    1.031775
# zip_code                                          1    0.000044
# dti                                            1711    0.075686
# delinq_2yrs                                      29    0.001283
# earliest_cr_line                                 29    0.001283
# inq_last_6mths                                   30    0.001327
# mths_since_last_delinq                      1158502   51.246003
# ...

# %%
# drop the columns where 80% or more data is missing, these columns are not necessary.
df_loan1 = df_loan.dropna(axis=1, thresh=int(0.80*len(df_loan)))
df_loan1.head()
print(df_loan1.shape)
df_loan1.info()
# Out:
# (2260668, 87)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Data columns (total 87 columns):
# loan_amnt                     int64
# funded_amnt                   int64
# funded_amnt_inv               float64
# term                          object
# int_rate                      float64
# installment                   float64
# grade                         object
# sub_grade                     object
# emp_title                     object
# emp_length                    object
# home_ownership                object
# annual_inc                    float64
# verification_status           object
# issue_d                       object
# loan_status                   object
# pymnt_plan                    object
# purpose                       object
# title                         object
# zip_code                      object
# addr_state                    object
# dti                           float64
# delinq_2yrs                   float64
# ...

# %%
''' several of the columns or features are "object" type
These need to be changed to category before we can convert those to 
mappings and numbers. So define a function to convert 
object types and string types to category type'''

#the module comes from teachers' knn_Model
def str_to_cat(my_df):
    for p,q in my_df.items(): #my_df.items() is a generator in Python
        if pd.api.types.is_string_dtype(q): 
            my_df[p] = q.astype('category').cat.as_ordered()
    return my_df

# %%
# Apply the str_to_cat function
df_loan2 = str_to_cat(df_loan1)
df_loan2.info()
# Out:
# /Users/maqiang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Data columns (total 87 columns):
# loan_amnt                     int64
# funded_amnt                   int64
# funded_amnt_inv               float64
# term                          category
# int_rate                      float64
# installment                   float64
# grade                         category
# sub_grade                     category
# emp_title                     category
# emp_length                    category
# home_ownership                category
# ...
